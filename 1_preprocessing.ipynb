# %%
# !pip install mido
# Out:
# Collecting mido
#   Downloading mido-1.3.3-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from mido) (24.2)
# Downloading mido-1.3.3-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: mido
# Successfully installed mido-1.3.3

# %%
import pandas as pd
import numpy as np
import pickle
import glob
from collections import Counter

import mido
from mido import Message, MidiFile, MidiTrack, MetaMessage

import warnings
warnings.filterwarnings('ignore')

# %%
data_path = "./data"
model_path = "./model"

# %%
df = pd.read_csv(f"{data_path}/csvs/2345.csv")
df.head(15)
# Out:
#     start_time  end_time  instrument  note  start_beat  end_beat note_value
# 0        22494     30173           1    37        0.00  0.489583     Eighth
# 1        27102     34270           1    44        0.25  0.489583     Eighth
# 2        30686     37854           1    44        0.50  0.489583     Eighth
# 3        30686     37854           1    49        0.50  0.489583     Eighth
# 4        34270     42462           1    52        0.75  0.489583     Eighth
# 5        37854     46046           1    56        1.00  0.489583     Eighth
# 6        37854     46046           1    37        1.00  0.489583     Eighth
# 7        42462     49118           1    49        1.25  0.489583     Eighth
# 8        46046     52190           1    52        1.50  0.489583     Eighth
# 9        46046     52190           1    44        1.50  0.489583     Eighth
# 10       49118     55774           1    56        1.75  0.489583     Eighth
# 11       52190     58846           1    61        2.00  0.489583     Eighth
# 12       52190     58846           1    37        2.00  0.489583     Eighth
# 13       55774     61918           1    52        2.25  0.489583     Eighth
# 14       58846     64478           1    56        2.50  0.489583     Eighth

# %%
def midi_to_note_dataframe(midi_path):
    mid = mido.MidiFile(midi_path)
    ticks_per_beat = mid.ticks_per_beat

    temp = False
    count = 0
    numerator, denominator = 0, 0
    for msg in mid.tracks[0]:
        if msg.type == "time_signature":
            if not temp:
                numerator, denominator = msg.numerator, msg.denominator
            count += 1


    print(f"Time signature: {numerator}/{denominator}\n# of Signature Changes: {count}")

    notes = []
    note_stack = {}  # (track, channel, note) -> (start_tick, velocity, tempo)

    for i, track in enumerate(mid.tracks):
        abs_tick = 0
        tempo = 500000  # Default tempo (120 BPM)

        for msg in track:
            abs_tick += msg.time

            if msg.type == 'set_tempo':
                tempo = msg.tempo

            if msg.type == 'note_on' and msg.velocity > 0:
                key = (i, msg.channel, msg.note)
                note_stack[key] = (abs_tick, msg.velocity, tempo)

            elif (msg.type == 'note_off') or (msg.type == 'note_on' and msg.velocity == 0):
                key = (i, msg.channel, msg.note)
                if key in note_stack:
                    start_tick, velocity, start_tempo = note_stack.pop(key)
                    duration_ticks = abs_tick - start_tick
                    start_time_sec = mido.tick2second(start_tick, ticks_per_beat, start_tempo)
                    duration_sec = mido.tick2second(duration_ticks, ticks_per_beat, start_tempo)
                    notes.append({
                        'hand': "Right" if i==1 else "Left",
                        'channel': msg.channel,
                        'note': msg.note,
                        'velocity': velocity,
                        'start_beat': start_time_sec * (denominator/2),
                        'duration': duration_sec * (denominator/2)
                    })

    return pd.DataFrame(notes)

# %%
def create_df(midi_file):
    def fix_note_value(note_value):
        return note_value.replace(" ", "")

    _id = midi_file.split("_")[0]

    mid = mido.MidiFile(f"{data_path}/midis/{midi_file}")
    df_original = pd.read_csv(f"{data_path}/csvs/{_id}.csv")

    df_original = df_original.drop(columns=["start_time", "end_time", "instrument"])
    df_original = df_original.rename(columns={"end_beat": "duration"})
    df_original["note_value"] = df_original["note_value"].apply(fix_note_value)
    df_original["duration"] = df_original["duration"].round(6)
    df_original["start_beat"] = df_original["start_beat"].round(6)

    df = midi_to_note_dataframe(f"{data_path}/midis/{midi_file}")
    df["duration"] = df["duration"].round(6)
    df["start_beat"] = df["start_beat"].round(6)

    print(f"Length of parsed df: {len(df)}\nLength of original df: {len(df_original)}")
    print(f"# of left and right notes: {len(df[df['hand'] == 'Left'])}, {len(df[df['hand'] == 'Right'])}")

    df = df.merge(df_original[['note', 'start_beat', 'duration', 'note_value']],
                on=['note', 'start_beat', 'duration'], how='left')
    df.sort_values(by=["start_beat"], inplace=True)
    df.index = [i for i in range(len(df))]

    num_nans = len(df[df['note_value'].isna()])
    print(f"# of nans as note values: {num_nans}")

    if num_nans > 35:
        return None
    else:
        df.dropna(inplace=True)
        return df

# %%
df = create_df("2345_ps14_03.mid")
df.head(15)
# Out:
# Time signature: 4/4
# # of Signature Changes: 1
# Length of parsed df: 6549
# Length of original df: 6548
# # of left and right notes: 3077, 3472
# # of nans as note values: 1
#      hand  channel  note  velocity  start_beat  duration note_value
# 0    Left        1    37        80        0.00  0.489583     Eighth
# 1   Right        0    44        80        0.25  0.489583     Eighth
# 2    Left        1    44        80        0.50  0.489583     Eighth
# 3   Right        0    49        80        0.50  0.489583     Eighth
# 4   Right        0    52        80        0.75  0.489583     Eighth
# 5    Left        1    37        80        1.00  0.489583     Eighth
# 6   Right        0    56        80        1.00  0.489583     Eighth
# 7   Right        0    49        80        1.25  0.489583     Eighth
# 8    Left        1    44        80        1.50  0.489583     Eighth
# 9   Right        0    52        80        1.50  0.489583     Eighth
# 10  Right        0    56        80        1.75  0.489583     Eighth
# 11   Left        1    37        80        2.00  0.489583     Eighth
# 12  Right        0    61        80        2.00  0.489583     Eighth
# 13  Right        0    52        80        2.25  0.489583     Eighth
# 14  Right        0    56        80        2.50  0.489583     Eighth

# %%
# Convert MIDI note numbers to note names (e.g., 60 -> C4)
def midi_to_note_name(midi_number):
    note_names = ['C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B']
    octave = (midi_number // 12) - 1
    note = note_names[midi_number % 12]
    return f"{note}{octave}"

# Function to group and process chords
def form_chords(df):
    df["note_name"] = df["note"].apply(midi_to_note_name)
    df["chord"] = ""
    grouped = df.groupby(["hand", "start_beat"])

    records = []

    for (hand, start_beat), group in grouped:
        if len(group) == 1:
            row = group.iloc[0].copy()
            row["chord"] = row["note_name"]
            records.append(row)
        else:
            # Chord name
            chord_notes = sorted(group["note_name"].tolist(), reverse=True)
            chord_label = "_".join(chord_notes)

            # Most frequent note_value
            most_common_note_value = Counter(group["note_value"]).most_common(1)[0][0]

            # Longest duration
            max_duration = group["duration"].max()

            # Create one representative row for the chord
            row = group.iloc[0].copy()
            row["chord"] = chord_label
            row["note_value"] = most_common_note_value
            row["duration"] = max_duration
            records.append(row)

    df = pd.DataFrame(records)
    df.drop(columns=["note_name"], inplace=True)
    df.sort_values(by="start_beat", inplace=True)

    return df

# %%
df = form_chords(df)
df.head(15)
# Out:
#      hand  channel  note  velocity  start_beat  duration note_value chord
# 0    Left        1    37        80        0.00  0.489583     Eighth   C#2
# 1   Right        0    44        80        0.25  0.489583     Eighth   G#2
# 3   Right        0    49        80        0.50  0.489583     Eighth   C#3
# 2    Left        1    44        80        0.50  0.489583     Eighth   G#2
# 4   Right        0    52        80        0.75  0.489583     Eighth    E3
# 6   Right        0    56        80        1.00  0.489583     Eighth   G#3
# 5    Left        1    37        80        1.00  0.489583     Eighth   C#2
# 7   Right        0    49        80        1.25  0.489583     Eighth   C#3
# 9   Right        0    52        80        1.50  0.489583     Eighth    E3
# 8    Left        1    44        80        1.50  0.489583     Eighth   G#2
# 10  Right        0    56        80        1.75  0.489583     Eighth   G#3
# 11   Left        1    37        80        2.00  0.489583     Eighth   C#2
# 12  Right        0    61        80        2.00  0.489583     Eighth   C#4
# 13  Right        0    52        80        2.25  0.489583     Eighth    E3
# 15   Left        1    44        80        2.50  0.489583     Eighth   G#2

# %%
for file in glob.glob(f"{data_path}/midis/*.mid"):
    print(file)
    file_name = file.split("/")[-1]
    file_id = file_name.split("_")[0]

    df = create_df(file_name)

    if df is None:
        continue

    df = form_chords(df)
    df.to_csv(f"{data_path}/preprocessed_csvs/{file_id}.csv")
# Out:
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2345_ps14_03.mid
# Time signature: 4/4
# # of Signature Changes: 1
# Length of parsed df: 6549
# Length of original df: 6548
# # of left and right notes: 3077, 3472
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2374_ps19_02.mid
# Time signature: 6/8
# # of Signature Changes: 1
# Length of parsed df: 2027
# Length of original df: 2026
# # of left and right notes: 1040, 987
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2359_ps15_04.mid
# Time signature: 6/8
# # of Signature Changes: 2
# Length of parsed df: 2638
# Length of original df: 2638
# # of left and right notes: 1030, 1608
# # of nans as note values: 0
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2371_ps09_02.mid
# Time signature: 3/4
# # of Signature Changes: 1
# Length of parsed df: 1275
# Length of original df: 1274
# # of left and right notes: 521, 754
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2373_ps19_01.mid
# Time signature: 2/4
# # of Signature Changes: 2
# Length of parsed df: 1761
# Length of original df: 1760
# # of left and right notes: 886, 875
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2372_ps09_03.mid
# Time signature: 4/4
# # of Signature Changes: 2
# Length of parsed df: 1772
# Length of original df: 1771
# # of left and right notes: 673, 1099
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2358_ps15_03.mid
# Time signature: 3/4
# # of Signature Changes: 1
# Length of parsed df: 1213
# Length of original df: 1213
# # of left and right notes: 645, 568
# # of nans as note values: 0
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2357_ps15_02.mid
# Time signature: 2/4
# # of Signature Changes: 1
# Length of parsed df: 2388
# Length of original df: 2387
# # of left and right notes: 997, 1391
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2390_ps17_03.mid
# Time signature: 3/8
# # of Signature Changes: 1
# Length of parsed df: 4281
# Length of original df: 4279
# # of left and right notes: 2061, 2220
# # of nans as note values: 2
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2388_ps17_01.mid
# Time signature: 4/4
# # of Signature Changes: 1
# Length of parsed df: 3982
# Length of original df: 3980
# # of left and right notes: 1645, 2337
# # of nans as note values: 2
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2389_ps17_02.mid
# Time signature: 3/4
# # of Signature Changes: 1
# Length of parsed df: 1691
# Length of original df: 1691
# # of left and right notes: 760, 931
# # of nans as note values: 0
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2405_ps31_02.mid
# Time signature: 2/4
# # of Signature Changes: 1
# Length of parsed df: 1343
# Length of original df: 1342
# # of left and right notes: 534, 809
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2411_ps13_02.mid
# Time signature: 3/4
# # of Signature Changes: 1
# Length of parsed df: 1458
# Length of original df: 1425
# # of left and right notes: 846, 612
# # of nans as note values: 33
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2404_ps31_01.mid
# Time signature: 3/4
# # of Signature Changes: 1
# Length of parsed df: 2900
# Length of original df: 2899
# # of left and right notes: 1609, 1291
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2410_ps13_01.mid
# Time signature: 4/4
# # of Signature Changes: 3
# Length of parsed df: 2095
# Length of original df: 2094
# # of left and right notes: 931, 1164
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2424_ps01_03.mid
# Time signature: 3/4
# # of Signature Changes: 2
# Length of parsed df: 1596
# Length of original df: 1596
# # of left and right notes: 742, 854
# # of nans as note values: 0
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2422_ps01_01.mid
# Time signature: 2/2
# # of Signature Changes: 2
# Length of parsed df: 2180
# Length of original df: 2180
# # of left and right notes: 1145, 1035
# # of nans as note values: 0
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2406_ps31_03.mid
# Time signature: 6/8
# # of Signature Changes: 9
# Length of parsed df: 3812
# Length of original df: 3811
# # of left and right notes: 2216, 1596
# # of nans as note values: 3790
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2423_ps01_02.mid
# Time signature: 3/4
# # of Signature Changes: 2
# Length of parsed df: 1357
# Length of original df: 1356
# # of left and right notes: 623, 734
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2441_ps29_01.mid
# Time signature: 4/4
# # of Signature Changes: 1
# Length of parsed df: 8417
# Length of original df: 8414
# # of left and right notes: 3770, 4647
# # of nans as note values: 3
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2442_ps29_02.mid
# Time signature: 3/4
# # of Signature Changes: 7
# Length of parsed df: 1881
# Length of original df: 1880
# # of left and right notes: 829, 1052
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2443_ps29_03.mid
# Time signature: 6/8
# # of Signature Changes: 1
# Length of parsed df: 5189
# Length of original df: 5188
# # of left and right notes: 2712, 2477
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2444_ps29_04.mid
# Time signature: 3/4
# # of Signature Changes: 5
# Length of parsed df: 8444
# Length of original df: 8438
# # of left and right notes: 4071, 4373
# # of nans as note values: 6
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2436_ps21_01.mid
# Time signature: 4/4
# # of Signature Changes: 1
# Length of parsed df: 8625
# Length of original df: 8610
# # of left and right notes: 4378, 4247
# # of nans as note values: 13
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2487_ps04_03.mid
# Time signature: 3/4
# # of Signature Changes: 1
# Length of parsed df: 2963
# Length of original df: 2963
# # of left and right notes: 1322, 1641
# # of nans as note values: 0
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2471_ps03_02.mid
# Time signature: 4/8
# # of Signature Changes: 1
# Length of parsed df: 1466
# Length of original df: 1465
# # of left and right notes: 480, 986
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2488_ps04_04.mid
# Time signature: 2/4
# # of Signature Changes: 2
# Length of parsed df: 4137
# Length of original df: 4136
# # of left and right notes: 2264, 1873
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2473_ps03_04.mid
# Time signature: 3/4
# # of Signature Changes: 2
# Length of parsed df: 4484
# Length of original df: 4483
# # of left and right notes: 1924, 2560
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2472_ps03_03.mid
# Time signature: 3/4
# # of Signature Changes: 2
# Length of parsed df: 2371
# Length of original df: 2371
# # of left and right notes: 972, 1399
# # of nans as note values: 0
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2486_ps04_02.mid
# Time signature: 3/4
# # of Signature Changes: 1
# Length of parsed df: 1485
# Length of original df: 1484
# # of left and right notes: 629, 856
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2509_ps02_01.mid
# Time signature: 2/4
# # of Signature Changes: 2
# Length of parsed df: 4042
# Length of original df: 4042
# # of left and right notes: 1823, 2219
# # of nans as note values: 0
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2512_ps02_04.mid
# Time signature: 4/4
# # of Signature Changes: 1
# Length of parsed df: 3757
# Length of original df: 3756
# # of left and right notes: 1777, 1980
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2510_ps02_02.mid
# Time signature: 3/4
# # of Signature Changes: 1
# Length of parsed df: 1440
# Length of original df: 1439
# # of left and right notes: 678, 762
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2550_ps24_02.mid
# Time signature: 2/4
# # of Signature Changes: 1
# Length of parsed df: 1812
# Length of original df: 1811
# # of left and right notes: 722, 1090
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2557_ps30_03.mid
# Time signature: 3/4
# # of Signature Changes: 8
# Length of parsed df: 5951
# Length of original df: 5950
# # of left and right notes: 2914, 3037
# # of nans as note values: 3994
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2566_ps11_04.mid
# Time signature: 2/4
# # of Signature Changes: 2
# Length of parsed df: 3454
# Length of original df: 3454
# # of left and right notes: 1545, 1909
# # of nans as note values: 0
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2530_ps32_01.mid
# Time signature: 4/4
# # of Signature Changes: 2
# Length of parsed df: 5462
# Length of original df: 5460
# # of left and right notes: 2670, 2792
# # of nans as note values: 2
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2538_ps20_02.mid
# Time signature: 3/4
# # of Signature Changes: 2
# Length of parsed df: 1279
# Length of original df: 1278
# # of left and right notes: 688, 591
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2555_ps30_01.mid
# Time signature: 2/4
# # of Signature Changes: 6
# Length of parsed df: 1497
# Length of original df: 1496
# # of left and right notes: 626, 871
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2537_ps20_01.mid
# Time signature: 4/4
# # of Signature Changes: 1
# Length of parsed df: 2354
# Length of original df: 2354
# # of left and right notes: 1090, 1264
# # of nans as note values: 0
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2564_ps11_02.mid
# Time signature: 3/8
# # of Signature Changes: 1
# Length of parsed df: 2187
# Length of original df: 2186
# # of left and right notes: 1136, 1051
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2568_ps27_02.mid
# Time signature: 2/4
# # of Signature Changes: 2
# Length of parsed df: 4013
# Length of original df: 4012
# # of left and right notes: 2163, 1850
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2567_ps27_01.mid
# Time signature: 3/4
# # of Signature Changes: 2
# Length of parsed df: 2630
# Length of original df: 2628
# # of left and right notes: 1319, 1311
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2531_ps32_02.mid
# Time signature: 3/16
# # of Signature Changes: 8
# Length of parsed df: 8036
# Length of original df: 8033
# # of left and right notes: 3552, 4484
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2527_ps05_01.mid
# Time signature: 3/4
# # of Signature Changes: 1
# Length of parsed df: 2858
# Length of original df: 2858
# # of left and right notes: 1404, 1454
# # of nans as note values: 0
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2542_ps28_03.mid
# Time signature: 2/4
# # of Signature Changes: 3
# Length of parsed df: 5497
# Length of original df: 5496
# # of left and right notes: 2583, 2914
# # of nans as note values: 4945
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2529_ps05_03.mid
# Time signature: 4/4
# # of Signature Changes: 2
# Length of parsed df: 2756
# Length of original df: 2755
# # of left and right notes: 1240, 1516
# # of nans as note values: 0
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2540_ps28_01.mid
# Time signature: 6/8
# # of Signature Changes: 1
# Length of parsed df: 1285
# Length of original df: 1284
# # of left and right notes: 560, 725
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2528_ps05_02.mid
# Time signature: 2/4
# # of Signature Changes: 5
# Length of parsed df: 1604
# Length of original df: 1603
# # of left and right notes: 696, 908
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2575_ps08_02.mid
# Time signature: 2/4
# # of Signature Changes: 1
# Length of parsed df: 1640
# Length of original df: 1639
# # of left and right notes: 587, 1053
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2611_ps07_02.mid
# Time signature: 3/8
# # of Signature Changes: 1
# Length of parsed df: 2070
# Length of original df: 2069
# # of left and right notes: 860, 1210
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2593_ps18_01.mid
# Time signature: 3/4
# # of Signature Changes: 1
# Length of parsed df: 4606
# Length of original df: 4606
# # of left and right notes: 1954, 2652
# # of nans as note values: 0
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2596_ps18_04.mid
# Time signature: 3/4
# # of Signature Changes: 2
# Length of parsed df: 3406
# Length of original df: 3399
# # of left and right notes: 1620, 1786
# # of nans as note values: 7
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2618_ps06_01.mid
# Time signature: 2/4
# # of Signature Changes: 2
# Length of parsed df: 3557
# Length of original df: 3557
# # of left and right notes: 1794, 1763
# # of nans as note values: 0
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2581_ps22_01.mid
# Time signature: 3/4
# # of Signature Changes: 4
# Length of parsed df: 3033
# Length of original df: 3031
# # of left and right notes: 1292, 1741
# # of nans as note values: 2
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2603_ps26_01.mid
# Time signature: 2/2
# # of Signature Changes: 2
# Length of parsed df: 3308
# Length of original df: 3307
# # of left and right notes: 1502, 1806
# # of nans as note values: 3221
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2608_ps16_03.mid
# Time signature: 4/4
# # of Signature Changes: 2
# Length of parsed df: 4137
# Length of original df: 4137
# # of left and right notes: 1958, 2179
# # of nans as note values: 0
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2582_ps22_02.mid
# Time signature: 2/4
# # of Signature Changes: 1
# Length of parsed df: 4628
# Length of original df: 4628
# # of left and right notes: 2067, 2561
# # of nans as note values: 0
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2607_ps16_02.mid
# Time signature: 3/8
# # of Signature Changes: 5
# Length of parsed df: 4411
# Length of original df: 4409
# # of left and right notes: 2006, 2405
# # of nans as note values: 2
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2576_ps08_03.mid
# Time signature: 4/4
# # of Signature Changes: 2
# Length of parsed df: 2392
# Length of original df: 2389
# # of left and right notes: 1102, 1290
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2590_ps12_03.mid
# Time signature: 4/4
# # of Signature Changes: 2
# Length of parsed df: 2032
# Length of original df: 2021
# # of left and right notes: 798, 1234
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2619_ps06_02.mid
# Time signature: 3/4
# # of Signature Changes: 2
# Length of parsed df: 1516
# Length of original df: 1516
# # of left and right notes: 636, 880
# # of nans as note values: 0
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2588_ps12_01.mid
# Time signature: 3/8
# # of Signature Changes: 2
# Length of parsed df: 3311
# Length of original df: 3310
# # of left and right notes: 1326, 1985
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2591_ps12_04.mid
# Time signature: 2/4
# # of Signature Changes: 2
# Length of parsed df: 2334
# Length of original df: 2334
# # of left and right notes: 935, 1399
# # of nans as note values: 0
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2595_ps18_03.mid
# Time signature: 3/4
# # of Signature Changes: 2
# Length of parsed df: 1476
# Length of original df: 1475
# # of left and right notes: 625, 851
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2594_ps18_02.mid
# Time signature: 2/4
# # of Signature Changes: 1
# Length of parsed df: 3008
# Length of original df: 3006
# # of left and right notes: 1571, 1437
# # of nans as note values: 2
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2633_ps10_03.mid
# Time signature: 3/8
# # of Signature Changes: 2
# Length of parsed df: 1998
# Length of original df: 1997
# # of left and right notes: 951, 1047
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2620_ps06_03.mid
# Time signature: 2/4
# # of Signature Changes: 2
# Length of parsed df: 2291
# Length of original df: 2291
# # of left and right notes: 992, 1299
# # of nans as note values: 0
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2632_ps10_02.mid
# Time signature: 4/4
# # of Signature Changes: 2
# Length of parsed df: 2058
# Length of original df: 2057
# # of left and right notes: 774, 1284
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2678_ps10_01.mid
# Time signature: 2/4
# # of Signature Changes: 2
# Length of parsed df: 3374
# Length of original df: 3373
# # of left and right notes: 1359, 2015
# # of nans as note values: 1
# /content/drive/MyDrive/Colab Notebooks/grad_proj/data/midis/2677_ps09_01.mid
# Time signature: 4/4
# # of Signature Changes: 1
# Length of parsed df: 3460
# Length of original df: 3459
# # of left and right notes: 1688, 1772
# # of nans as note values: 1

# %%
def create_token_sequence(df, quantize=False, quantize_step=0.125):
    def round_beat(x):
        return round(x / quantize_step) * quantize_step if quantize else x

    df = df.copy()
    if quantize:
        df["start_beat"] = df["start_beat"].apply(round_beat)
        df["duration"] = df["duration"].apply(round_beat)

    df = df.sort_values(by=["start_beat", "hand"])  # overall ordering
    sequence = []
    prev_beat = 0.0

    for _, row in df.iterrows():
        current_beat = row["start_beat"]
        time_shift = round_beat(current_beat - prev_beat)
        sequence.append(f"TIME_SHIFT_{time_shift:.3f}")
        prev_beat = current_beat

        hand = row["hand"]
        sequence.append(f"[HAND_{hand.upper()}]")

        chord_str = row["chord"]
        note_value = row["note_value"]

        if "_" in chord_str:
            notes = chord_str.split("_")
            sequence.append("[CHORD_START]")
            for note in notes:
                sequence.append(f"NOTE_{note}")
            sequence.append(f"VALUE_{note_value}")
            sequence.append("[CHORD_END]")
        else:
            sequence.append(f"NOTE_{chord_str}")
            sequence.append(f"VALUE_{note_value}")

    return sequence

# %%
class MusicTokenizer:
    def __init__(self):
        self.token_to_id = {}
        self.id_to_token = {}

    def build_vocab(self, sequences):
        for line in sequences:
            parts = line.strip().split()
            for token in parts:
                if token not in self.token_to_id:
                    token_id = len(self.token_to_id)
                    self.token_to_id[token] = token_id
                    self.id_to_token[token_id] = token

    def encode(self, sequences):
        return [[self.token_to_id[token] for token in line.strip().split()] for line in sequences]

    def decode(self, id_sequences):
        return [" ".join([self.id_to_token[token_id] for token_id in line]) for line in id_sequences]

    def decode2(self, id_sequences):
        return [" ".join([self.id_to_token[id] for id in id_sequences])]

# %%
def prepare_training_data(token_sequence, tokenizer, seq_len=256):
    tokens = []
    for token in token_sequence:
        tokens.append(token)

    token_ids = [tokenizer.token_to_id[token] for token in tokens if token in tokenizer.token_to_id.keys()]

    for i in range(len(token_ids) - seq_len):
        x.append(token_ids[i:i+seq_len])
        y.append(token_ids[i+seq_len])

# %%
x, y = [], []
tokenizer = MusicTokenizer()
max_seq_length = 512

for file in glob.glob(f"{data_path}/preprocessed_csvs/*.csv"):
    df = pd.read_csv(file)
    df = df.drop(columns=["Unnamed: 0"])

    sequence = create_token_sequence(df)
    tokenizer.build_vocab(sequence)
    prepare_training_data(sequence, tokenizer, seq_len=max_seq_length)

# %%
import random
from sklearn.model_selection import train_test_split

# Use a local random generator
rng = random.Random(42)

def train_test_val_split(x, y, tokenizer, seq_len):
    # Shuffle before splitting
    combined = list(zip(x, y))
    rng.shuffle(combined)
    x, y = zip(*combined)

    x = np.array(x, dtype=np.int32)
    y = np.array(y, dtype=np.int32)

    # Split into train (80%) and temp (20%)
    x_train, x_temp, y_train, y_temp = train_test_split(x, y, test_size=0.2, random_state=42)

    # Split temp into validation (10%) and test (10%)
    x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5, random_state=42)

    return x_train, x_test, x_val, y_train, y_test, y_val

# %%
x_train, x_test, x_val, y_train, y_test, y_val = train_test_val_split(x, y, tokenizer, seq_len=max_seq_length)

# %%
np.save(f'{data_path}/x_train.npy', x_train)
np.save(f'{data_path}/x_test.npy', x_test)
np.save(f'{data_path}/x_val.npy', x_val)
np.save(f'{data_path}/y_train.npy', y_train)
np.save(f'{data_path}/y_test.npy', y_test)
np.save(f'{data_path}/y_val.npy', y_val)

# %%
with open(f"{model_path}/tokenizer.pkl", "wb") as f:
    pickle.dump(tokenizer, f)
